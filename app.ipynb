# %%
from ultralytics import YOLO
import cv2
import numpy as np

# ======================
# LOAD MODEL & VIDEO
# ======================
model = YOLO("0809.pt")
cap = cv2.VideoCapture("video_27.mp4")

# Get video properties
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter("demo_output.mp4", fourcc, fps, (width, height))

# ======================
# ROI VÙNG XE (INITIAL)
# ======================
# ROI sẽ được cập nhật động dựa vào vị trí của xe
TRUCK_ROI_INITIAL = np.array([
    (320, 230),
    (880, 230),
    (950, 580),
    (300, 580)
], dtype=np.int32)
truck_roi = TRUCK_ROI_INITIAL.copy()

# ======================
# PARAMETERS
# ======================
MIN_CONSECUTIVE_UPWARD = 5  # phải di chuyển lên ít nhất 5 frame LIÊN TỤC (rất khắt)
UPWARD_THRESHOLD = 2.0      # mỗi frame phải di chuyển lên ít nhất 2px
DOWNWARD_THRESHOLD = 0.5    # nếu di chuyển xuống > 0.5px thì reset ngay

# ======================
# BIẾN ĐẾM
# ======================
counted_ids = set()         # IDs đã đếm
track_state = {}            # tracking state
total_boxes = 0
truck_x_offset = 0          # dùng để follow truck
last_truck_box = None       # box của xe từ frame trước

# ======================
# HÀM
# ======================
def point_in_roi(point, roi):
    """Check if point is inside ROI polygon"""
    return cv2.pointPolygonTest(roi, point, False) >= 0

def find_truck_in_frame(boxes, y_threshold=300):
    """
    Tìm xe trong frame - sử dụng box lớn nhất (cách đơn giản)
    """
    if len(boxes) == 0:
        return None
    
    # Lấy box có diện tích lớn nhất (có thể là xe)
    max_area = 0
    truck_box = None
    for box in boxes:
        x1, y1, x2, y2 = box
        area = (x2 - x1) * (y2 - y1)
        if area > max_area and (y2 - y1) >= 30:  # chiều cao >= 30px
            max_area = area
            truck_box = box
    
    return truck_box

def get_dynamic_roi(truck_box, roi_initial):
    """
    Cập nhật ROI theo vị trí xe
    Nếu không detect được truck, dùng ROI cố định
    """
    if truck_box is None:
        return roi_initial
    
    tx1, ty1, tx2, ty2 = truck_box
    truck_cx = (tx1 + tx2) / 2
    
    # Tính offset từ vị trí xe so với ROI ban đầu
    roi_cx = (roi_initial[0][0] + roi_initial[1][0]) / 2
    offset = truck_cx - roi_cx
    
    # Dịch ROI theo offset
    new_roi = roi_initial.copy().astype(float)
    new_roi[:, 0] += offset  # dịch X
    
    return new_roi.astype(np.int32)

def get_dynamic_roi_from_boxes(box_centers, roi_initial):
    """
    Cập nhật ROI dựa vào trung bình vị trí của tất cả boxes
    Cách này tốt hơn vì theo dõi "khối boxes" trên xe
    """
    if len(box_centers) == 0:
        return roi_initial
    
    # Tính centroid của tất cả boxes
    avg_x = sum([x for x, y in box_centers]) / len(box_centers)
    
    # Tính offset từ centroid boxes so với ROI ban đầu
    roi_cx = (roi_initial[0][0] + roi_initial[1][0]) / 2
    offset = avg_x - roi_cx
    
    # Dịch ROI theo offset
    new_roi = roi_initial.copy().astype(float)
    new_roi[:, 0] += offset  # dịch X
    
    return new_roi.astype(np.int32)


# ======================
# MAIN LOOP
# ======================
frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    frame_count += 1

    # Detect + Track
    results = model.track(
        frame,
        persist=True,
        conf=0.4,
        iou=0.5,
        tracker="bytetrack.yaml"
    )

    # Detect truck nếu có boxes
    truck_box = None
    
    if results[0].boxes is not None:
        boxes = results[0].boxes.xyxy.cpu().numpy()
        truck_box = find_truck_in_frame(boxes)
    
    # Sử dụng ROI CỐ ĐỊNH (không dịch động) để tránh sai đếm
    truck_roi = TRUCK_ROI_INITIAL
    
    # Draw ROI
    cv2.polylines(frame, [truck_roi], True, (255, 0, 0), 2)
    
    # Draw truck box nếu detected
    if truck_box is not None:
        tx1, ty1, tx2, ty2 = map(int, truck_box)
        cv2.rectangle(frame, (tx1, ty1), (tx2, ty2), (0, 165, 255), 3)
        cv2.putText(frame, "TRUCK", (tx1, ty1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 165, 255), 2)

    if results[0].boxes is not None and results[0].boxes.id is not None:
        boxes = results[0].boxes.xyxy.cpu().numpy()
        ids = results[0].boxes.id.cpu().numpy().astype(int)

        for box, track_id in zip(boxes, ids):
            x1, y1, x2, y2 = map(int, box)
            cx = int((x1 + x2) / 2)
            cy = int((y1 + y2) / 2)

            # Initialize state
            if track_id not in track_state:
                track_state[track_id] = {
                    'last_y': cy,
                    'consecutive_upward': 0,  # số frame LIÊN TỤC di chuyển lên
                    'was_in_roi': False,
                    'frames_in_roi': 0,      # số frame đã ở trong ROI
                }

            state = track_state[track_id]
            is_in_roi = point_in_roi((cx, cy), truck_roi)  # Use dynamic truck_roi
            
            # Check upward movement (Y decreasing)
            dy = state['last_y'] - cy  # positive = up
            
            if is_in_roi:
                # Box trong ROI - tăng frame counter
                state['frames_in_roi'] += 1
                
                # Chỉ bắt đầu kiểm tra upward motion sau khi box ở trong ROI >= 2 frame
                if state['frames_in_roi'] >= 2:
                    # Kiểm tra: di chuyển lên đủ mạnh
                    if dy > UPWARD_THRESHOLD:  # di chuyển lên >= 2px
                        state['consecutive_upward'] += 1
                    elif dy < -DOWNWARD_THRESHOLD:  # di chuyển xuống > 0.5px → reset ngay
                        state['consecutive_upward'] = 0
                    # else: di chuyển nhẹ hoặc đứng yên, giữ nguyên counter
                else:
                    # Frame đầu tiên vào ROI - reset counter
                    state['consecutive_upward'] = 0
                
                state['was_in_roi'] = True
                
                # Count nếu:
                # 1. Đủ 5 frame LIÊN TỤC di chuyển lên mạnh (>= 2px)
                # 2. Đã ở ROI >= 2 frame
                # 3. Chưa đếm trước đó
                if state['consecutive_upward'] >= MIN_CONSECUTIVE_UPWARD and state['frames_in_roi'] >= 2 and track_id not in counted_ids:
                    total_boxes += 1
                    counted_ids.add(track_id)
                    print(f"✅ COUNTED ID {track_id} | TOTAL = {total_boxes} | frame {frame_count} | up={state['consecutive_upward']} | roi_frames={state['frames_in_roi']}")
            else:
                # Box ngoài ROI - reset counter
                state['consecutive_upward'] = 0
                state['frames_in_roi'] = 0
                state['was_in_roi'] = False
            
            # Determine color
            if track_id in counted_ids:
                box_color = (0, 255, 0)  # GREEN - counted
            elif is_in_roi and state['consecutive_upward'] >= 1:
                box_color = (0, 255, 255)  # YELLOW - lifting (1+ frames)
            elif is_in_roi:
                box_color = (255, 165, 0)  # CYAN - in ROI but not lifting
            else:
                box_color = (0, 0, 255)  # RED - outside ROI

            # Draw
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)
            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            
            # Label with counter showing progress
            label = f"ID {track_id}"
            if is_in_roi and state['frames_in_roi'] >= 2:
                if state['consecutive_upward'] > 0:
                    label += f" ↑{state['consecutive_upward']}/{MIN_CONSECUTIVE_UPWARD}"
            cv2.putText(
                frame,
                label,
                (x1, y1 - 5),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                box_color,
                2
            )

            # Update last position
            state['last_y'] = cy

    # Display total
    cv2.putText(
        frame,
        f"TOTAL BOXES: {total_boxes}",
        (30, 50),
        cv2.FONT_HERSHEY_SIMPLEX,
        1.5,
        (0, 255, 0),
        3
    )
    cv2.putText(
        frame,
        f"Frame: {frame_count}",
        (30, 100),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.8,
        (255, 255, 255),
        2
    )
    
    # Legend
    cv2.putText(
        frame,
        "GREEN=Counted | YELLOW=Lifting... | CYAN=In ROI | RED=Outside",
        (30, frame.shape[0] - 20),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.6,
        (200, 200, 200),
        1
    )

    cv2.imshow("BOX COUNTING", frame)
    out.write(frame)  # Write frame to video
    if cv2.waitKey(1) & 0xFF == 27:
        break

# Cleanup
cap.release()
out.release()
cv2.destroyAllWindows()

print("\n" + "="*60)
print(f"✅ FINAL TOTAL BOXES: {total_boxes}")
print("="*60)
# Out:
# Starting box counting (v12 - Simplified upward motion detection)
#
#
# 0: 384x640 2 boxs, 56.9ms
# Speed: 1.7ms preprocess, 56.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 boxs, 56.9ms
# Speed: 1.7ms preprocess, 56.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 boxs, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 boxs, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 3 boxs, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 3 boxs, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 boxs, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 boxs, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 boxs, 43.5ms
# Speed: 0.9ms preprocess, 43.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 boxs, 43.5ms
# Speed: 0.9ms preprocess, 43.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 3 boxs, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 3 boxs, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 3 boxs, 52.0ms
# Speed: 15.4ms preprocess, 52.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 3 boxs, 52.0ms
# Speed: 15.4ms preprocess, 52.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.0ms
# Speed: 1.3ms preprocess, 42.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.0ms
# Speed: 1.3ms preprocess, 42.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.0ms
# Speed: 1.2ms preprocess, 43.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.0ms
# Speed: 1.2ms preprocess, 43.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.1ms
# Speed: 1.0ms preprocess, 41.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.1ms
# Speed: 1.0ms preprocess, 41.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 40.8ms
# Speed: 1.0ms preprocess, 40.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 40.8ms
# Speed: 1.0ms preprocess, 40.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.2ms
# Speed: 1.0ms preprocess, 41.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.2ms
# Speed: 1.0ms preprocess, 41.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.2ms
# Speed: 0.9ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.2ms
# Speed: 0.9ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.4ms
# Speed: 1.2ms preprocess, 41.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.4ms
# Speed: 1.2ms preprocess, 41.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.7ms
# Speed: 1.1ms preprocess, 42.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.7ms
# Speed: 1.1ms preprocess, 42.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 42.2ms
# Speed: 0.9ms preprocess, 42.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 42.2ms
# Speed: 0.9ms preprocess, 42.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 43.9ms
# Speed: 0.9ms preprocess, 43.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 43.9ms
# Speed: 0.9ms preprocess, 43.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 44.0ms
# Speed: 1.4ms preprocess, 44.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 44.0ms
# Speed: 1.4ms preprocess, 44.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ LIFTED ID=13 | frame 62
# ✅ LIFTED ID=16 | frame 62
#
# ✅ LIFTED ID=13 | frame 62
# ✅ LIFTED ID=16 | frame 62
#
# 0: 384x640 7 boxs, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 63.6ms
# Speed: 3.1ms preprocess, 63.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 63.6ms
# Speed: 3.1ms preprocess, 63.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.9ms
# Speed: 1.0ms preprocess, 42.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.9ms
# Speed: 1.0ms preprocess, 42.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.7ms
# Speed: 1.3ms preprocess, 41.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.7ms
# Speed: 1.3ms preprocess, 41.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.7ms
# Speed: 1.2ms preprocess, 41.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.7ms
# Speed: 1.2ms preprocess, 41.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.8ms
# Speed: 0.9ms preprocess, 42.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.8ms
# Speed: 0.9ms preprocess, 42.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.8ms
# Speed: 0.9ms preprocess, 41.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.8ms
# Speed: 0.9ms preprocess, 41.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.3ms
# Speed: 1.0ms preprocess, 41.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.3ms
# Speed: 1.0ms preprocess, 41.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 56.6ms
# Speed: 2.2ms preprocess, 56.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 56.6ms
# Speed: 2.2ms preprocess, 56.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 46.5ms
# Speed: 1.1ms preprocess, 46.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 46.5ms
# Speed: 1.1ms preprocess, 46.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.2ms
# Speed: 0.9ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.2ms
# Speed: 0.9ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.9ms
# Speed: 1.3ms preprocess, 41.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.9ms
# Speed: 1.3ms preprocess, 41.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.0ms
# Speed: 1.1ms preprocess, 41.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.0ms
# Speed: 1.1ms preprocess, 41.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.4ms preprocess, 43.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.4ms preprocess, 43.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.1ms
# Speed: 1.1ms preprocess, 44.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.1ms
# Speed: 1.1ms preprocess, 44.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.5ms
# Speed: 1.1ms preprocess, 44.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.5ms
# Speed: 1.1ms preprocess, 44.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.9ms
# Speed: 1.1ms preprocess, 43.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.9ms
# Speed: 1.1ms preprocess, 43.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.1ms
# Speed: 0.9ms preprocess, 41.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.1ms
# Speed: 0.9ms preprocess, 41.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.9ms
# Speed: 1.0ms preprocess, 42.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.9ms
# Speed: 1.0ms preprocess, 42.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.3ms
# Speed: 1.1ms preprocess, 41.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.3ms
# Speed: 1.1ms preprocess, 41.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.4ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.4ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 77.9ms
# Speed: 0.9ms preprocess, 77.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 77.9ms
# Speed: 0.9ms preprocess, 77.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.5ms
# Speed: 1.1ms preprocess, 41.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.5ms
# Speed: 1.1ms preprocess, 41.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.6ms
# Speed: 0.9ms preprocess, 43.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.6ms
# Speed: 0.9ms preprocess, 43.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.0ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.0ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.0ms
# Speed: 0.9ms preprocess, 43.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.0ms
# Speed: 0.9ms preprocess, 43.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 90.4ms
# Speed: 1.1ms preprocess, 90.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 90.4ms
# Speed: 1.1ms preprocess, 90.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 57.4ms
# Speed: 1.4ms preprocess, 57.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 57.4ms
# Speed: 1.4ms preprocess, 57.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 49.2ms
# Speed: 1.1ms preprocess, 49.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 49.2ms
# Speed: 1.1ms preprocess, 49.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 47.8ms
# Speed: 1.1ms preprocess, 47.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 47.8ms
# Speed: 1.1ms preprocess, 47.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 46.2ms
# Speed: 1.3ms preprocess, 46.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 46.2ms
# Speed: 1.3ms preprocess, 46.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.8ms
# Speed: 1.1ms preprocess, 44.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.8ms
# Speed: 1.1ms preprocess, 44.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.8ms
# Speed: 1.3ms preprocess, 45.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.8ms
# Speed: 1.3ms preprocess, 45.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.1ms
# Speed: 1.2ms preprocess, 45.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.1ms
# Speed: 1.2ms preprocess, 45.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 48.4ms
# Speed: 1.1ms preprocess, 48.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 48.4ms
# Speed: 1.1ms preprocess, 48.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.0ms
# Speed: 1.2ms preprocess, 45.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.0ms
# Speed: 1.2ms preprocess, 45.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 82.3ms
# Speed: 1.2ms preprocess, 82.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 82.3ms
# Speed: 1.2ms preprocess, 82.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.9ms
# Speed: 1.2ms preprocess, 43.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.9ms
# Speed: 1.2ms preprocess, 43.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.1ms
# Speed: 1.1ms preprocess, 45.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.1ms
# Speed: 1.1ms preprocess, 45.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 53.0ms
# Speed: 1.1ms preprocess, 53.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 53.0ms
# Speed: 1.1ms preprocess, 53.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 46.3ms
# Speed: 1.1ms preprocess, 46.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 46.3ms
# Speed: 1.1ms preprocess, 46.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 47.9ms
# Speed: 1.0ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 47.9ms
# Speed: 1.0ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
# !pip install labelImg

# %%
from ultralytics import YOLO
import cv2
import numpy as np

# ======================
# LOAD MODEL & VIDEO
# ======================
model = YOLO("0809.pt")
cap = cv2.VideoCapture("video_27.mp4")

# Get video properties
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter("demo_output.mp4", fourcc, fps, (width, height))

# ======================
# ROI VÙNG XE (INITIAL)
# ======================
# ROI sẽ được cập nhật động dựa vào vị trí của xe
TRUCK_ROI_INITIAL = np.array([
    (320, 230),
    (880, 230),
    (950, 580),
    (300, 580)
], dtype=np.int32)
truck_roi = TRUCK_ROI_INITIAL.copy()

# ======================
# PARAMETERS
# ======================
MIN_CONSECUTIVE_UPWARD = 5  # phải di chuyển lên ít nhất 5 frame LIÊN TỤC (rất khắt)
UPWARD_THRESHOLD = 2.0      # mỗi frame phải di chuyển lên ít nhất 2px
DOWNWARD_THRESHOLD = 0.5    # nếu di chuyển xuống > 0.5px thì reset ngay

# ======================
# BIẾN ĐẾM
# ======================
counted_ids = set()         # IDs đã đếm
track_state = {}            # tracking state
total_boxes = 0
truck_x_offset = 0          # dùng để follow truck
last_truck_box = None       # box của xe từ frame trước

# ======================
# HÀM
# ======================
def point_in_roi(point, roi):
    """Check if point is inside ROI polygon"""
    return cv2.pointPolygonTest(roi, point, False) >= 0

def find_truck_in_frame(boxes, y_threshold=300):
    """
    Tìm xe trong frame - sử dụng box lớn nhất (cách đơn giản)
    """
    if len(boxes) == 0:
        return None
    
    # Lấy box có diện tích lớn nhất (có thể là xe)
    max_area = 0
    truck_box = None
    for box in boxes:
        x1, y1, x2, y2 = box
        area = (x2 - x1) * (y2 - y1)
        if area > max_area and (y2 - y1) >= 30:  # chiều cao >= 30px
            max_area = area
            truck_box = box
    
    return truck_box

def get_dynamic_roi(truck_box, roi_initial):
    """
    Cập nhật ROI theo vị trí xe
    Nếu không detect được truck, dùng ROI cố định
    """
    if truck_box is None:
        return roi_initial
    
    tx1, ty1, tx2, ty2 = truck_box
    truck_cx = (tx1 + tx2) / 2
    
    # Tính offset từ vị trí xe so với ROI ban đầu
    roi_cx = (roi_initial[0][0] + roi_initial[1][0]) / 2
    offset = truck_cx - roi_cx
    
    # Dịch ROI theo offset
    new_roi = roi_initial.copy().astype(float)
    new_roi[:, 0] += offset  # dịch X
    
    return new_roi.astype(np.int32)

def get_dynamic_roi_from_boxes(box_centers, roi_initial):
    """
    Cập nhật ROI dựa vào trung bình vị trí của tất cả boxes
    Cách này tốt hơn vì theo dõi "khối boxes" trên xe
    """
    if len(box_centers) == 0:
        return roi_initial
    
    # Tính centroid của tất cả boxes
    avg_x = sum([x for x, y in box_centers]) / len(box_centers)
    
    # Tính offset từ centroid boxes so với ROI ban đầu
    roi_cx = (roi_initial[0][0] + roi_initial[1][0]) / 2
    offset = avg_x - roi_cx
    
    # Dịch ROI theo offset
    new_roi = roi_initial.copy().astype(float)
    new_roi[:, 0] += offset  # dịch X
    
    return new_roi.astype(np.int32)


# ======================
# MAIN LOOP
# ======================
frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    frame_count += 1

    # Detect + Track
    results = model.track(
        frame,
        persist=True,
        conf=0.4,
        iou=0.5,
        tracker="bytetrack.yaml"
    )

    # Detect truck nếu có boxes
    truck_box = None
    
    if results[0].boxes is not None:
        boxes = results[0].boxes.xyxy.cpu().numpy()
        truck_box = find_truck_in_frame(boxes)
    
    # Sử dụng ROI CỐ ĐỊNH (không dịch động) để tránh sai đếm
    truck_roi = TRUCK_ROI_INITIAL
    
    # Draw ROI
    cv2.polylines(frame, [truck_roi], True, (255, 0, 0), 2)
    
    # Draw truck box nếu detected
    if truck_box is not None:
        tx1, ty1, tx2, ty2 = map(int, truck_box)
        cv2.rectangle(frame, (tx1, ty1), (tx2, ty2), (0, 165, 255), 3)
        cv2.putText(frame, "TRUCK", (tx1, ty1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 165, 255), 2)

    if results[0].boxes is not None and results[0].boxes.id is not None:
        boxes = results[0].boxes.xyxy.cpu().numpy()
        ids = results[0].boxes.id.cpu().numpy().astype(int)

        for box, track_id in zip(boxes, ids):
            x1, y1, x2, y2 = map(int, box)
            cx = int((x1 + x2) / 2)
            cy = int((y1 + y2) / 2)

            # Initialize state
            if track_id not in track_state:
                track_state[track_id] = {
                    'last_y': cy,
                    'consecutive_upward': 0,  # số frame LIÊN TỤC di chuyển lên
                    'was_in_roi': False,
                    'frames_in_roi': 0,      # số frame đã ở trong ROI
                    'already_counted': False,  # đã đếm chưa
                }

            state = track_state[track_id]
            
            # Nếu đã đếm rồi thì bỏ qua toàn bộ logic, chỉ vẽ
            if track_id in counted_ids:
                state['already_counted'] = True
                # Vẽ và skip phần logic
            else:
                # Chưa đếm - tiếp tục kiểm tra logic
                is_in_roi = point_in_roi((cx, cy), truck_roi)
                
                # Check upward movement (Y decreasing)
                dy = state['last_y'] - cy  # positive = up
                
                if is_in_roi:
                    # Box trong ROI - tăng frame counter
                    state['frames_in_roi'] += 1
                    
                    # Chỉ bắt đầu kiểm tra upward motion sau khi box ở trong ROI >= 2 frame
                    if state['frames_in_roi'] >= 2:
                        # Kiểm tra: di chuyển lên đủ mạnh
                        if dy > UPWARD_THRESHOLD:  # di chuyển lên >= 2px
                            state['consecutive_upward'] += 1
                        elif dy < -DOWNWARD_THRESHOLD:  # di chuyển xuống > 0.5px → reset ngay
                            state['consecutive_upward'] = 0
                        # else: di chuyển nhẹ hoặc đứng yên, giữ nguyên counter
                    else:
                        # Frame đầu tiên vào ROI - reset counter
                        state['consecutive_upward'] = 0
                    
                    state['was_in_roi'] = True
                    
                    # Count nếu:
                    # 1. Đủ 5 frame LIÊN TỤC di chuyển lên mạnh (>= 2px)
                    # 2. Đã ở ROI >= 2 frame
                    # 3. Chưa đếm trước đó
                    if state['consecutive_upward'] >= MIN_CONSECUTIVE_UPWARD and state['frames_in_roi'] >= 2 and track_id not in counted_ids:
                        total_boxes += 1
                        counted_ids.add(track_id)
                        state['already_counted'] = True
                        print(f"✅ COUNTED ID {track_id} | TOTAL = {total_boxes} | frame {frame_count} | up={state['consecutive_upward']} | roi_frames={state['frames_in_roi']}")
                else:
                    # Box ngoài ROI - reset counter
                    state['consecutive_upward'] = 0
                    state['frames_in_roi'] = 0
                    state['was_in_roi'] = False
            
            # Determine color dựa trên trạng thái
            if state['already_counted'] or track_id in counted_ids:
                box_color = (0, 255, 0)  # GREEN - counted (vĩnh viễn)
            elif is_in_roi and state['consecutive_upward'] >= 1:
                box_color = (0, 255, 255)  # YELLOW - lifting (1+ frames)
            elif is_in_roi:
                box_color = (255, 165, 0)  # CYAN - in ROI but not lifting
            else:
                box_color = (0, 0, 255)  # RED - outside ROI

            # Draw
            cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)
            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            
            # Label with counter showing progress
            label = f"ID {track_id}"
            if state['already_counted']:
                label += " ✓DONE"  # Đánh dấu đã đếm
            elif is_in_roi and state['frames_in_roi'] >= 2:
                if state['consecutive_upward'] > 0:
                    label += f" ↑{state['consecutive_upward']}/{MIN_CONSECUTIVE_UPWARD}"
            
            cv2.putText(
                frame,
                label,
                (x1, y1 - 5),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                box_color,
                2
            )

            # Update last position
            state['last_y'] = cy

    # Display total
    cv2.putText(
        frame,
        f"TOTAL BOXES: {total_boxes}",
        (30, 50),
        cv2.FONT_HERSHEY_SIMPLEX,
        1.5,
        (0, 255, 0),
        3
    )
    cv2.putText(
        frame,
        f"Frame: {frame_count}",
        (30, 100),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.8,
        (255, 255, 255),
        2
    )
    
    # Legend
    cv2.putText(
        frame,
        "GREEN=Counted | YELLOW=Lifting... | CYAN=In ROI | RED=Outside",
        (30, frame.shape[0] - 20),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.6,
        (200, 200, 200),
        1
    )

    cv2.imshow("BOX COUNTING", frame)
    out.write(frame)  # Write frame to video
    if cv2.waitKey(1) & 0xFF == 27:
        break

# Cleanup
cap.release()
out.release()
cv2.destroyAllWindows()

print("\n" + "="*60)
print(f"✅ FINAL TOTAL BOXES: {total_boxes}")
print("="*60)
# Out:
# 0: 384x640 1 box, 122.2ms
# Speed: 10.9ms preprocess, 122.2ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 122.2ms
# Speed: 10.9ms preprocess, 122.2ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 57.1ms
# Speed: 1.6ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 57.1ms
# Speed: 1.6ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 44.9ms
# Speed: 1.3ms preprocess, 44.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 44.9ms
# Speed: 1.3ms preprocess, 44.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 3 boxs, 44.8ms
# Speed: 1.2ms preprocess, 44.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 3 boxs, 44.8ms
# Speed: 1.2ms preprocess, 44.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 45.6ms
# Speed: 1.1ms preprocess, 45.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 45.6ms
# Speed: 1.1ms preprocess, 45.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 42.9ms
# Speed: 1.0ms preprocess, 42.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 42.9ms
# Speed: 1.0ms preprocess, 42.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 boxs, 46.5ms
# Speed: 1.3ms preprocess, 46.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 boxs, 46.5ms
# Speed: 1.3ms preprocess, 46.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 2 boxs, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 boxs, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.6ms
# Speed: 1.2ms preprocess, 42.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.6ms
# Speed: 1.2ms preprocess, 42.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.9ms
# Speed: 1.2ms preprocess, 42.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.9ms
# Speed: 1.2ms preprocess, 42.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 46.1ms
# Speed: 0.9ms preprocess, 46.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 46.1ms
# Speed: 0.9ms preprocess, 46.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.1ms
# Speed: 1.2ms preprocess, 45.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.1ms
# Speed: 1.2ms preprocess, 45.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.5ms
# Speed: 0.9ms preprocess, 43.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.5ms
# Speed: 0.9ms preprocess, 43.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 49.8ms
# Speed: 1.1ms preprocess, 49.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 49.8ms
# Speed: 1.1ms preprocess, 49.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.2ms preprocess, 44.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.2ms preprocess, 44.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ COUNTED ID 6 | TOTAL = 1 | frame 40 | up=5 | roi_frames=29
#
# ✅ COUNTED ID 6 | TOTAL = 1 | frame 40 | up=5 | roi_frames=29
#
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ COUNTED ID 7 | TOTAL = 2 | frame 41 | up=5 | roi_frames=28
# ✅ COUNTED ID 10 | TOTAL = 3 | frame 41 | up=5 | roi_frames=23
#
# ✅ COUNTED ID 7 | TOTAL = 2 | frame 41 | up=5 | roi_frames=28
# ✅ COUNTED ID 10 | TOTAL = 3 | frame 41 | up=5 | roi_frames=23
#
# 0: 384x640 5 boxs, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ COUNTED ID 3 | TOTAL = 4 | frame 42 | up=5 | roi_frames=33
#
# ✅ COUNTED ID 3 | TOTAL = 4 | frame 42 | up=5 | roi_frames=33
#
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.5ms
# Speed: 1.2ms preprocess, 44.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.5ms
# Speed: 1.2ms preprocess, 44.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ✅ COUNTED ID 4 | TOTAL = 5 | frame 47 | up=5 | roi_frames=7
#
# ✅ COUNTED ID 4 | TOTAL = 5 | frame 47 | up=5 | roi_frames=7
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 43.7ms
# Speed: 1.3ms preprocess, 43.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 43.7ms
# Speed: 1.3ms preprocess, 43.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 44.1ms
# Speed: 1.1ms preprocess, 44.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 44.1ms
# Speed: 1.1ms preprocess, 44.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.2ms
# Speed: 1.2ms preprocess, 45.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.2ms
# Speed: 1.2ms preprocess, 45.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.1ms
# Speed: 1.6ms preprocess, 43.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.1ms
# Speed: 1.6ms preprocess, 43.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 46.9ms
# Speed: 1.1ms preprocess, 46.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 46.9ms
# Speed: 1.1ms preprocess, 46.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 82.3ms
# Speed: 1.1ms preprocess, 82.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 82.3ms
# Speed: 1.1ms preprocess, 82.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.4ms
# Speed: 1.2ms preprocess, 45.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.4ms
# Speed: 1.2ms preprocess, 45.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.3ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.3ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.2ms preprocess, 44.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.2ms preprocess, 44.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.2ms
# Speed: 1.0ms preprocess, 44.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.2ms
# Speed: 1.0ms preprocess, 44.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.7ms
# Speed: 1.2ms preprocess, 44.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.7ms
# Speed: 1.2ms preprocess, 44.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.9ms
# Speed: 1.1ms preprocess, 43.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.9ms
# Speed: 1.1ms preprocess, 43.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.5ms
# Speed: 1.1ms preprocess, 45.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.5ms
# Speed: 1.1ms preprocess, 45.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 42.7ms
# Speed: 1.1ms preprocess, 42.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 42.7ms
# Speed: 1.1ms preprocess, 42.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.4ms
# Speed: 0.9ms preprocess, 44.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.4ms
# Speed: 0.9ms preprocess, 44.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.1ms
# Speed: 1.3ms preprocess, 44.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.1ms
# Speed: 1.3ms preprocess, 44.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 47.8ms
# Speed: 1.1ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 47.8ms
# Speed: 1.1ms preprocess, 47.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.4ms preprocess, 44.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.4ms preprocess, 44.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 53.3ms
# Speed: 1.1ms preprocess, 53.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 53.3ms
# Speed: 1.1ms preprocess, 53.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 48.2ms
# Speed: 1.1ms preprocess, 48.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 48.2ms
# Speed: 1.1ms preprocess, 48.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 48.0ms
# Speed: 1.6ms preprocess, 48.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 48.0ms
# Speed: 1.6ms preprocess, 48.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 85.3ms
# Speed: 1.3ms preprocess, 85.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 85.3ms
# Speed: 1.3ms preprocess, 85.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.5ms
# Speed: 1.1ms preprocess, 45.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.5ms
# Speed: 1.1ms preprocess, 45.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.1ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.1ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.5ms
# Speed: 1.1ms preprocess, 44.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.5ms
# Speed: 1.1ms preprocess, 44.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.9ms
# Speed: 1.2ms preprocess, 45.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.9ms
# Speed: 1.2ms preprocess, 45.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.3ms
# Speed: 1.1ms preprocess, 45.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.3ms
# Speed: 1.1ms preprocess, 45.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.4ms
# Speed: 0.9ms preprocess, 44.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.4ms
# Speed: 0.9ms preprocess, 44.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.2ms
# Speed: 0.9ms preprocess, 45.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.2ms
# Speed: 0.9ms preprocess, 45.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.2ms
# Speed: 0.9ms preprocess, 44.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.2ms
# Speed: 0.9ms preprocess, 44.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.0ms
# Speed: 0.9ms preprocess, 43.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.0ms
# Speed: 0.9ms preprocess, 43.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.1ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.1ms preprocess, 44.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 47.2ms
# Speed: 1.0ms preprocess, 47.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 47.2ms
# Speed: 1.0ms preprocess, 47.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.3ms preprocess, 44.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.3ms preprocess, 44.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.2ms preprocess, 43.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.3ms
# Speed: 1.2ms preprocess, 43.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 48.6ms
# Speed: 0.9ms preprocess, 48.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 48.6ms
# Speed: 0.9ms preprocess, 48.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.3ms
# Speed: 1.1ms preprocess, 45.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.3ms
# Speed: 1.1ms preprocess, 45.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 86.7ms
# Speed: 1.3ms preprocess, 86.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 86.7ms
# Speed: 1.3ms preprocess, 86.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.5ms
# Speed: 1.2ms preprocess, 45.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.5ms
# Speed: 1.2ms preprocess, 45.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.4ms
# Speed: 2.4ms preprocess, 45.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.4ms
# Speed: 2.4ms preprocess, 45.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.3ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 43.7ms
# Speed: 1.3ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.6ms
# Speed: 0.9ms preprocess, 44.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.6ms
# Speed: 0.9ms preprocess, 44.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 44.3ms
# Speed: 1.4ms preprocess, 44.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 44.3ms
# Speed: 1.4ms preprocess, 44.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 45.0ms
# Speed: 1.0ms preprocess, 45.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 45.0ms
# Speed: 1.0ms preprocess, 45.0ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.1ms preprocess, 45.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.1ms preprocess, 45.4ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 44.1ms
# Speed: 1.1ms preprocess, 44.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 44.1ms
# Speed: 1.1ms preprocess, 44.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 44.2ms
# Speed: 1.2ms preprocess, 44.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 44.2ms
# Speed: 1.2ms preprocess, 44.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 45.8ms
# Speed: 1.1ms preprocess, 45.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 45.8ms
# Speed: 1.1ms preprocess, 45.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ...
#
#
# 0: 384x640 7 boxs, 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 55.1ms
# Speed: 1.2ms preprocess, 55.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 55.1ms
# Speed: 1.2ms preprocess, 55.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 8 boxs, 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 boxs, 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 8 boxs, 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 boxs, 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 8 boxs, 51.0ms
# Speed: 1.2ms preprocess, 51.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 boxs, 51.0ms
# Speed: 1.2ms preprocess, 51.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 8 boxs, 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 boxs, 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 8 boxs, 46.8ms
# Speed: 1.2ms preprocess, 46.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 boxs, 46.8ms
# Speed: 1.2ms preprocess, 46.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 8 boxs, 46.4ms
# Speed: 1.1ms preprocess, 46.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 boxs, 46.4ms
# Speed: 1.1ms preprocess, 46.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 8 boxs, 47.1ms
# Speed: 1.3ms preprocess, 47.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 boxs, 47.1ms
# Speed: 1.3ms preprocess, 47.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 8 boxs, 50.3ms
# Speed: 1.3ms preprocess, 50.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 boxs, 50.3ms
# Speed: 1.3ms preprocess, 50.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 8 boxs, 50.8ms
# Speed: 1.5ms preprocess, 50.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 boxs, 50.8ms
# Speed: 1.5ms preprocess, 50.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 46.9ms
# Speed: 1.4ms preprocess, 46.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 46.9ms
# Speed: 1.4ms preprocess, 46.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 8 boxs, 49.9ms
# Speed: 1.1ms preprocess, 49.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 boxs, 49.9ms
# Speed: 1.1ms preprocess, 49.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 54.7ms
# Speed: 2.1ms preprocess, 54.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 54.7ms
# Speed: 2.1ms preprocess, 54.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 49.3ms
# Speed: 1.5ms preprocess, 49.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 49.3ms
# Speed: 1.5ms preprocess, 49.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 44.8ms
# Speed: 1.0ms preprocess, 44.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 44.8ms
# Speed: 1.0ms preprocess, 44.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 45.0ms
# Speed: 1.0ms preprocess, 45.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 45.0ms
# Speed: 1.0ms preprocess, 45.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 7 boxs, 48.1ms
# Speed: 1.7ms preprocess, 48.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 boxs, 48.1ms
# Speed: 1.7ms preprocess, 48.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 46.2ms
# Speed: 1.1ms preprocess, 46.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 46.2ms
# Speed: 1.1ms preprocess, 46.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 46.0ms
# Speed: 1.3ms preprocess, 46.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 46.0ms
# Speed: 1.3ms preprocess, 46.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 49.1ms
# Speed: 1.1ms preprocess, 49.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 49.1ms
# Speed: 1.1ms preprocess, 49.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.3ms preprocess, 44.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.9ms
# Speed: 1.3ms preprocess, 44.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 45.0ms
# Speed: 1.3ms preprocess, 45.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 45.0ms
# Speed: 1.3ms preprocess, 45.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 51.0ms
# Speed: 1.1ms preprocess, 51.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 51.0ms
# Speed: 1.1ms preprocess, 51.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 45.8ms
# Speed: 1.1ms preprocess, 45.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 45.8ms
# Speed: 1.1ms preprocess, 45.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 88.1ms
# Speed: 1.0ms preprocess, 88.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 88.1ms
# Speed: 1.0ms preprocess, 88.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.3ms preprocess, 44.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 5 boxs, 44.6ms
# Speed: 1.3ms preprocess, 44.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 50.1ms
# Speed: 1.2ms preprocess, 50.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 50.1ms
# Speed: 1.2ms preprocess, 50.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 46.2ms
# Speed: 1.2ms preprocess, 46.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 46.2ms
# Speed: 1.2ms preprocess, 46.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 8 boxs, 46.1ms
# Speed: 1.1ms preprocess, 46.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 boxs, 46.1ms
# Speed: 1.1ms preprocess, 46.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 8 boxs, 44.7ms
# Speed: 1.2ms preprocess, 44.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 boxs, 44.7ms
# Speed: 1.2ms preprocess, 44.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 47.5ms
# Speed: 1.3ms preprocess, 47.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 47.5ms
# Speed: 1.3ms preprocess, 47.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 3 boxs, 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 3 boxs, 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 3 boxs, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 3 boxs, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 44.3ms
# Speed: 1.2ms preprocess, 44.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 44.3ms
# Speed: 1.2ms preprocess, 44.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 box, 45.5ms
# Speed: 1.3ms preprocess, 45.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 box, 45.5ms
# Speed: 1.3ms preprocess, 45.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.1ms preprocess, 47.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.1ms preprocess, 47.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.1ms preprocess, 46.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.1ms preprocess, 46.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 1.1ms preprocess, 46.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 46.6ms
# Speed: 1.1ms preprocess, 46.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 86.3ms
# Speed: 1.1ms preprocess, 86.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 86.3ms
# Speed: 1.1ms preprocess, 86.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 49.1ms
# Speed: 1.1ms preprocess, 49.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 49.1ms
# Speed: 1.1ms preprocess, 49.1ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.3ms preprocess, 46.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.3ms preprocess, 46.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 47.7ms
# Speed: 1.2ms preprocess, 47.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 47.7ms
# Speed: 1.2ms preprocess, 47.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.1ms preprocess, 47.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.1ms preprocess, 47.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.1ms preprocess, 46.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 46.2ms
# Speed: 1.1ms preprocess, 46.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 3 boxs, 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 3 boxs, 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 4 boxs, 47.0ms
# Speed: 0.9ms preprocess, 47.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 4 boxs, 47.0ms
# Speed: 0.9ms preprocess, 47.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 6 boxs, 47.3ms
# Speed: 1.3ms preprocess, 47.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 boxs, 47.3ms
# Speed: 1.3ms preprocess, 47.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 274
#     272     cv2.imshow("BOX COUNTING", frame)
#     273     out.write(frame)  # Write frame to video
# --> 274     if cv2.waitKey(1) & 0xFF == 27:
#     275         break
#     277 # Cleanup
#
# KeyboardInterrupt:
